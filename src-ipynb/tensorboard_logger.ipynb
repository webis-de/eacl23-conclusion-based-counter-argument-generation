# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir ../data/output/ca-final-models/ --host 0.0.0.0
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 879912.
