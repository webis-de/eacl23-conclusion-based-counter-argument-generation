# %% [markdown]
# ### This notebook is to jointly train BART-v2 model for both generating the conclusion and the counter

# %%
import os
import sys
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
sys.path.append('../src-py')

# %%
import transformers
import datasets
from utils import *
from mt_bart_v2 import *

print(f"Running on transformers v{transformers.__version__} and datasets v{datasets.__version__}")
# Out:
# Running on transformers v4.18.0 and datasets v2.1.0

# %%
import torch
import json

import nltk
import numpy as np
import pandas as pd

from pathlib import Path
from datasets import load_dataset, load_metric, Dataset

from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
pd.set_option('display.max_colwidth', None)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')

# %%
#This function to fine-tune different weighting schemes of the two loss functions
#conclusion gen loss and counter gen loss.
def get_model(params):
    compute_dynamic_weights=False
    conc_loss_weight=0.5 if params == None else params['conc_loss_weight']
    counter_loss_weight=0.5 if params == None else params['counter_loss_weight']
    attention_to_conc=False
    conc_decoder=True
    model     = BartModelV2.from_pretrained('facebook/bart-base', 
                                            compute_dynamic_weights=False, 
                                            conc_loss_weight = conc_loss_weight, 
                                            counter_loss_weight=counter_loss_weight, 
                                            attention_to_conc=attention_to_conc, 
                                            conc_decoder=conc_decoder).to(device)

    original_bart_model = BartModel.from_pretrained('facebook/bart-base').to(device)

    #load the weights of the two decoders
    model.conclusion_decoder.load_state_dict(original_bart_model.decoder.state_dict())

    data_collator= DataCollatorForSeq2Seq(tokenizer, model)
    
    return data_collator, model

# %%
data_fold = '../../../data-ceph/arguana/arg-generation/multi-taks-counter-argument-generation/'

# %%
#Taking unique posts from valid dataset and sample only 1500 instances
# valid_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_comp_remove_75sem_perc.pkl')
# valid_unique_df = valid_df.drop_duplicates('post_id')
# valid_sample_df = valid_unique_df.sample(1500)
# valid_sample_df.to_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_comp_remove_75sem_perc_sample.pkl')

# test_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/test_concusion_comp_remove_75sem_perc.pkl')
# test_unique_df = test_df.drop_duplicates('post_id')
# test_unique_df.to_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/test_concusion_comp_remove_75sem_perc_sample.pkl')

#Taking unique posts from valid dataset and sample only 1500 instances
# valid_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_all.pkl')
# valid_unique_df = valid_df.drop_duplicates('post_id')
# valid_sample_df = valid_unique_df.sample(1500)
# valid_sample_df.to_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_all_sample.pkl')

# test_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/test_concusion_all.pkl')
# test_unique_df = test_df.drop_duplicates('post_id')
# test_unique_df = test_df.sample(2500)
# test_unique_df.to_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/test_concusion_all_sample.pkl')

# %%
#Encoding function for joint generation of conclusion and counter
def preprocess_function(examples, tokenizer, premises_clm, counter_clm, conclusion_clm, 
                        max_input_length=512, max_conc_length=100, max_counter_length=200):
    premises    = examples[premises_clm]
    conclusions = examples[conclusion_clm]
    counters = examples[counter_clm]
    
        
    premises = [' '.join(x) for x in premises] if isinstance(premises[0], list) else premises
    counters = [' '.join(x) for x in counters] if isinstance(counters[0], list) else counters
    conclusions = [' '.join(x) for x in conclusions] if isinstance(conclusions[0], list) else conclusions
    
    model_inputs = tokenizer(premises, max_length=max_input_length, truncation=True, padding='max_length')
        
    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        counter_labels = tokenizer(counters, max_length=max_counter_length, truncation=True, padding='max_length')
        conclusion_labels = tokenizer(conclusions, max_length=max_conc_length, truncation=True, padding='max_length')

    model_inputs["conclusion_labels"] = conclusion_labels["input_ids"]
    model_inputs["conclusion_decoder_attention_mask"] = conclusion_labels['attention_mask']
    model_inputs["labels"] = counter_labels["input_ids"]
    model_inputs["decoder_attention_mask"] = counter_labels['attention_mask']
    
    return model_inputs

# %%
#downsample the training dataset
#tmp_ds = train_ds.train_test_split(0.005)
#train_ds = tmp_ds['test']

# %%
output_models_path = '/var/tmp/sile2804/ca-final-models/'

# %% [markdown]
# #### Fine-tune model using simple weighting scheme:

# %%
train_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/preprocessed_train_conclusion_all.pkl')
valid_df = pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_all.pkl')

# %%
train_df.columns
# Out:
# Index(['post_id', 'split', 'comment_id', 'title', 'post', 'n_sentences',
#        'counter', 'bot_comment', 'counter_conclusion', 'counter_conclusions'],
#       dtype='object')

# %%
valid_df = valid_df.drop_duplicates('post_id').sample(1000)
valid_df.to_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_all_sample.pkl')

# %%
train_ds = Dataset.from_pandas(train_df.drop_duplicates('post_id'))
valid_ds = Dataset.from_pandas(valid_df.drop_duplicates('post_id'))

# %%
train_tokenized_ds = train_ds.map(lambda x :preprocess_function(x, tokenizer, 'post', 'counter', 'title'), batched=True)
valid_tokenized_ds = valid_ds.map(lambda x :preprocess_function(x, tokenizer, 'post', 'counter', 'title'), batched=True)
# Out:
#   0%|          | 0/26 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
model = BartModelV2.from_pretrained('facebook/bart-large', compute_dynamic_weights=False, conc_loss_weight = 0.5, counter_loss_weight=0.5, conc_decoder=True).to(device)
original_bart_model = BartModel.from_pretrained('facebook/bart-large').to(device)
model.conclusion_decoder.load_state_dict(original_bart_model.decoder.state_dict())
data_collator= DataCollatorForSeq2Seq(tokenizer, model)

args = Seq2SeqTrainingArguments(
    output_models_path + "mt-model-baseline-weighting-scheme",
    evaluation_strategy = "steps",
    eval_steps=500,
    save_steps=500,
    learning_rate=5e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=5,
    num_train_epochs=6,
    load_best_model_at_end=True,
    predict_with_generate=True,
    metric_for_best_model='loss',
    label_names=['labels', 'conclusion_labels']
)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_tokenized_ds,
    eval_dataset=valid_tokenized_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=lambda x : compute_metrics(x, tokenizer)
)

trainer.train()
trainer.save_model()
# Out:
# Some weights of BartModelV2 were not initialized from the model checkpoint at facebook/bart-large and are newly initialized: ['conclusion_decoder.layernorm_embedding.weight', 'conclusion_decoder.embed_tokens.weight', 'conclusion_decoder.layernorm_embedding.bias', 'conclusion_decoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following columns in the training set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running training *****
#   Num examples = 25704
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9639
#     <div>
#
#       <progress value='9639' max='9639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9639/9639 1:05:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu Scores</th>
#       <th>Bert-fscores</th>
#       <th>Bert-fscore</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.917900</td>
#       <td>1.195952</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.042958</td>
#       <td>0.000385</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.550500</td>
#       <td>1.140719</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.051198</td>
#       <td>0.000623</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.493600</td>
#       <td>1.104544</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.042712</td>
#       <td>0.000558</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.480000</td>
#       <td>1.085377</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.041616</td>
#       <td>0.000334</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.452300</td>
#       <td>1.072465</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.041587</td>
#       <td>0.000387</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.421800</td>
#       <td>1.052911</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035724</td>
#       <td>0.000402</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.339200</td>
#       <td>1.048096</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.021071</td>
#       <td>0.000367</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.290500</td>
#       <td>1.038212</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.040583</td>
#       <td>0.000453</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.287400</td>
#       <td>1.032002</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.031088</td>
#       <td>0.000378</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.289800</td>
#       <td>1.027369</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.022899</td>
#       <td>0.000349</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.274800</td>
#       <td>1.020546</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.033050</td>
#       <td>0.000325</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.256600</td>
#       <td>1.017984</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.034081</td>
#       <td>0.000443</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.249900</td>
#       <td>1.012634</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.031815</td>
#       <td>0.000379</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.177100</td>
#       <td>1.013401</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.030274</td>
#       <td>0.000354</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.163000</td>
#       <td>1.008318</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.033451</td>
#       <td>0.000332</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.158600</td>
#       <td>1.007434</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.033248</td>
#       <td>0.000401</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.161200</td>
#       <td>1.002830</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.032433</td>
#       <td>0.000368</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.147600</td>
#       <td>1.001281</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.034926</td>
#       <td>0.000380</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.168400</td>
#       <td>1.000160</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.030884</td>
#       <td>0.000379</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/roberta-large/resolve/main/vocab.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# loading file https://huggingface.co/roberta-large/resolve/main/merges.txt from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/roberta-large/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# All the weights of RobertaModel were initialized from the model checkpoint at roberta-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModel for predictions without further training.
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 16
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-9500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-9500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-7500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/checkpoint-1000 (score: 0.05119798990660638).
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-baseline-weighting-scheme/special_tokens_map.json

# %%
print('Done')
# Out:
# Done

# %% [markdown]
# #### Train a dyanmic weighting model:

# %%
model = BartModelV2.from_pretrained('facebook/bart-large', compute_dynamic_weights=True, conc_decoder=True).to(device)
original_bart_model = BartModel.from_pretrained('facebook/bart-large').to(device)
model.conclusion_decoder.load_state_dict(original_bart_model.decoder.state_dict())
data_collator= DataCollatorForSeq2Seq(tokenizer, model)

args = Seq2SeqTrainingArguments(
    output_models_path + "mt-model-dynamic-weighting-scheme",
    evaluation_strategy = "steps",
    eval_steps=500,
    save_steps=500,
    learning_rate=5e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    weight_decay=0.01,
    save_total_limit=5,
    num_train_epochs=3,
    load_best_model_at_end=True,
    predict_with_generate=True,
    metric_for_best_model='bert-fscore',
    label_names=['labels', 'conclusion_labels']
)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_tokenized_ds,
    eval_dataset=valid_tokenized_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=lambda x : compute_metrics(x, tokenizer)
)

trainer.train()
trainer.save_model()
# Out:
# loading configuration file https://huggingface.co/facebook/bart-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/3f12fb71b844fcb7d591fdd4e55027da90d7b5dd6aa5430ad00ec6d76585f26c.bc22f15dc7ba074ee0a60bdd34c5f2fe3b6d746f89e765303376c51aff04e260
# Model config BartConfig {
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "transformers_version": "4.15.0",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/facebook/bart-large/resolve/main/pytorch_model.bin from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/d065edfe6954baf0b989a2063b26eb07e8c4d0b19354b5c74af9a51f5518df6e.6ca4df1a6ec59aa763989ceec10dff41dde19f0f0824b9f5d3fcd35a8abffdb2
# All model checkpoint weights were used when initializing BartModelV2.
#
# Some weights of BartModelV2 were not initialized from the model checkpoint at facebook/bart-large and are newly initialized: ['log_vars', 'conclusion_decoder.layernorm_embedding.weight', 'conclusion_decoder.embed_tokens.weight', 'conclusion_decoder.layernorm_embedding.bias', 'conclusion_decoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loading configuration file https://huggingface.co/facebook/bart-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/3f12fb71b844fcb7d591fdd4e55027da90d7b5dd6aa5430ad00ec6d76585f26c.bc22f15dc7ba074ee0a60bdd34c5f2fe3b6d746f89e765303376c51aff04e260
# Model config BartConfig {
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "transformers_version": "4.15.0",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/facebook/bart-large/resolve/main/pytorch_model.bin from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/d065edfe6954baf0b989a2063b26eb07e8c4d0b19354b5c74af9a51f5518df6e.6ca4df1a6ec59aa763989ceec10dff41dde19f0f0824b9f5d3fcd35a8abffdb2
# All model checkpoint weights were used when initializing BartModel.
#
# All the weights of BartModel were initialized from the model checkpoint at facebook/bart-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartModel for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running training *****
#   Num examples = 25704
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9639
#     <div>
#
#       <progress value='9639' max='9639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9639/9639 1:10:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu Scores</th>
#       <th>Bert-fscores</th>
#       <th>Bert-fscore</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.913200</td>
#       <td>1.182969</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.042776</td>
#       <td>0.000370</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.510800</td>
#       <td>1.108315</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.040106</td>
#       <td>0.000407</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.434700</td>
#       <td>1.067844</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.044828</td>
#       <td>0.000896</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.405300</td>
#       <td>1.036797</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.043300</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.363900</td>
#       <td>1.012464</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.036081</td>
#       <td>0.000455</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.325400</td>
#       <td>0.991186</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035286</td>
#       <td>0.000452</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.238200</td>
#       <td>0.982157</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.023371</td>
#       <td>0.000374</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.186500</td>
#       <td>0.968586</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.039315</td>
#       <td>0.000665</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.174900</td>
#       <td>0.957093</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.040442</td>
#       <td>0.000416</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.170400</td>
#       <td>0.947326</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.022037</td>
#       <td>0.000356</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.150600</td>
#       <td>0.938113</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.036457</td>
#       <td>0.000347</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.129300</td>
#       <td>0.931217</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035223</td>
#       <td>0.000439</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.118800</td>
#       <td>0.925523</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.029113</td>
#       <td>0.000351</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.052800</td>
#       <td>0.924194</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035356</td>
#       <td>0.000393</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.038900</td>
#       <td>0.918799</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035935</td>
#       <td>0.000369</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.033100</td>
#       <td>0.916377</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.033089</td>
#       <td>0.000362</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.033400</td>
#       <td>0.912217</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.034093</td>
#       <td>0.000399</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.020600</td>
#       <td>0.910474</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.035152</td>
#       <td>0.000363</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.035800</td>
#       <td>0.909005</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.029435</td>
#       <td>0.000385</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9000
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9000/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: bot_comment, title, post_id, post, counter, n_sentences, split, comment_id, __index_level_0__.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Warning: Empty reference sentence detected; setting recall to be 0.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9500
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9500/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [/var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-7500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/checkpoint-1500 (score: 0.04482765768832178).
# Saving model checkpoint to /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme
# Configuration saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/config.json
# Model weights saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/pytorch_model.bin
# tokenizer config file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/tokenizer_config.json
# Special tokens file saved in /var/tmp/sile2804/ca-final-models/mt-model-dynamic-weighting-scheme/special_tokens_map.json

# %% [markdown]
# -----------------

# %% [markdown]
# ### Finding best training parameters:

# %%
#train_ds = Dataset.from_pandas(pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/train_conclusion_comp_remove_75sem_perc.pkl'))
#valid_ds = Dataset.from_pandas(pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_comp_remove_75sem_perc_sample.pkl'))

train_ds = Dataset.from_pandas(pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/train_conclusion_all.pkl'))
valid_ds = Dataset.from_pandas(pd.read_pickle(data_fold+'/reddit_data/conclusion_and_ca_generation/valid_conclusion_all_sample.pkl'))

# %%
train_tokenized_ds = train_ds.map(lambda x :preprocess_function(x, tokenizer, 'post', 'counter', 'title'), batched=True)
valid_tokenized_ds = valid_ds.map(lambda x :preprocess_function(x, tokenizer, 'post', 'counter', 'title'), batched=True)
# Out:
#   0%|          | 0/296 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
for lr in [2e-5, 3e-5, 5e-5]:
    model = BartModelV2.from_pretrained('facebook/bart-base', compute_dynamic_weights=True, conc_decoder=True).to(device)
    original_bart_model = BartModel.from_pretrained('facebook/bart-base').to(device)
    model.conclusion_decoder.load_state_dict(original_bart_model.decoder.state_dict())
    data_collator= DataCollatorForSeq2Seq(tokenizer, model)

    args = Seq2SeqTrainingArguments(
        "../data/output/valid-ft-all/mt-model-{}".format(str(lr) + '-' + str(32)),
        evaluation_strategy = "steps",
        eval_steps=500,
        save_steps=500,
        learning_rate=lr,
        per_device_train_batch_size=32,
        per_device_eval_batch_size=32,
        weight_decay=0.01,
        save_total_limit=5,
        num_train_epochs=1,
        load_best_model_at_end=True,
        predict_with_generate=True,
        metric_for_best_model='bert-fscore',
        label_names=['labels', 'conclusion_labels']
    )

    trainer = Seq2SeqTrainer(
        model,
        args,
        train_dataset=train_tokenized_ds,
        eval_dataset=valid_tokenized_ds,
        data_collator=data_collator,
        tokenizer=tokenizer,
        compute_metrics=lambda x : compute_metrics(x, tokenizer)
    )

    trainer.train()
    trainer.save_model()
# Out:
# Some weights of BartModelV2 were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['conclusion_decoder.layernorm_embedding.weight', 'conclusion_decoder.embed_tokens.weight', 'conclusion_decoder.embed_positions.weight', 'conclusion_decoder.layernorm_embedding.bias', 'log_vars']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following columns in the training set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: post_id, post, comment_id, counter, n_sentences, split, __index_level_0__, title.
# ***** Running training *****
#   Num examples = 295914
#   Num Epochs = 1
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9248
#     <div>
#
#       <progress value='501' max='9248' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 501/9248 03:19 < 58:15, 2.50 it/s, Epoch 0.05/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu Scores</th>
#       <th>Bert-fscores</th>
#       <th>Bert-fscore</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.089600</td>
#       <td>1.214435</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0.022454</td>
#       <td>0.000629</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `BartModelV2.forward` and have been ignored: post_id, post, comment_id, counter, n_sentences, split, __index_level_0__, title.
# ***** Running Evaluation *****
#   Num examples = 1500
#   Batch size = 32
# /usr/local/lib/python3.6/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.9.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/roberta-large/resolve/main/vocab.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# loading file https://huggingface.co/roberta-large/resolve/main/merges.txt from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/roberta-large/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.9.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.9.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin from cache at /mnt/ceph/storage/data-tmp/2021//sile2804/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# All the weights of RobertaModel were initialized from the model checkpoint at roberta-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModel for predictions without further training.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bleu_scores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[]" of type <class 'list'> for key "eval/bert-fscores" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Saving model checkpoint to ../data/output/valid-ft-all/mt-model-2e-05-32/checkpoint-500
# Configuration saved in ../data/output/valid-ft-all/mt-model-2e-05-32/checkpoint-500/config.json
# Model weights saved in ../data/output/valid-ft-all/mt-model-2e-05-32/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ../data/output/valid-ft-all/mt-model-2e-05-32/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ../data/output/valid-ft-all/mt-model-2e-05-32/checkpoint-500/special_tokens_map.json
